# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\vishal\Downloads\netflix_movies.csv')

# %%
data
# Out:
#                                         url  \
# 0    https://www.netflix.com/title/80189221
# 1    https://www.netflix.com/title/81031373
# 2    https://www.netflix.com/title/80996601
# 3    https://www.netflix.com/title/81350429
# 4    https://www.netflix.com/title/81149184
# ..                                      ...
# 143  https://www.netflix.com/title/81021929
# 144  https://www.netflix.com/title/81123055
# 145  https://www.netflix.com/title/81036622
# 146  https://www.netflix.com/title/81464765
# 147  https://www.netflix.com/title/81435684
#
#                                                  name contentType  \
# 0                          The Haunting of Hill House    TVSeries
# 1    Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                       Love Is Blind    TVSeries
# 3                                        I Care a Lot       Movie
# 4                                  tick, tick...BOOM!       Movie
# ...

# %%
# using head()
data.head()
# Out:
#                                       url  \
# 0  https://www.netflix.com/title/80189221
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                name contentType  \
# 0                        The Haunting of Hill House    TVSeries
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          description contentRating  \
# 0  Flashing between past and present, a fractured...           18+
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %%
# using tail()
data.tail()
# Out:
#                                         url                             name  \
# 143  https://www.netflix.com/title/81021929                      Space Force
# 144  https://www.netflix.com/title/81123055                 In From the Cold
# 145  https://www.netflix.com/title/81036622                          Toy Boy
# 146  https://www.netflix.com/title/81464765  14 Peaks: Nothing Is Impossible
# 147  https://www.netflix.com/title/81435684                           Arcane
#
#     contentType                                        description  \
# 143    TVSeries  A four-star general begrudgingly teams up with...
# 144    TVSeries  Exposed as an ex-Russian spy, an American sing...
# 145    TVSeries  After seven years in a Málaga prison, a male s...
# 146       Movie  Fearless Nepali mountaineer Nimsdai Purja emba...
# 147    TVSeries  Amid the stark discord of twin cities Piltover...
#
#     contentRating             genre  \
# 143           16+       TV Comedies
# ...

# %%
# using shape
data.shape
# Out:
# (148, 21)

# %%
# using size
data.size
# Out:
# 3108

# %%
# using columns
data.columns
# Out:
# Index(['url', 'name', 'contentType', 'description', 'contentRating', 'genre',
#        'poster', 'formattedDuration', 'releasedDate', 'actors', 'director',
#        'creator', 'audio', 'subtitle', 'availableForOffline',
#        'numberOfSeasons', 'seasonStartDate', 'source', 'sourceLink', 'uniqId',
#        'scrapedAt'],
#       dtype='object')

# %%
# using dtypes
data.dtypes
# Out:
# url                     object
# name                    object
# contentType             object
# description             object
# contentRating           object
# genre                   object
# poster                  object
# formattedDuration       object
# releasedDate            object
# actors                  object
# director                object
# creator                 object
# audio                   object
# subtitle                object
# availableForOffline     object
# numberOfSeasons        float64
# seasonStartDate         object
# source                  object
# sourceLink              object
# uniqId                  object
# scrapedAt               object
# dtype: object

# %%
# using info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  148 non-null    object
#  1   name                 148 non-null    object
#  2   contentType          148 non-null    object
#  3   description          148 non-null    object
#  4   contentRating        148 non-null    object
#  5   genre                148 non-null    object
#  6   poster               148 non-null    object
#  7   formattedDuration    43 non-null     object
#  8   releasedDate         148 non-null    object
#  9   actors               132 non-null    object
#  10  director             51 non-null     object
#  11  creator              74 non-null     object
#  12  audio                43 non-null     object
#  13  subtitle             43 non-null     object
#  14  availableForOffline  148 non-null    object
# ...

# %%
# find  duplicate and removal function
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [url, name, contentType, description, contentRating, genre, poster, formattedDuration, releasedDate, actors, director, creator, audio, subtitle, availableForOffline, numberOfSeasons, seasonStartDate, source, sourceLink, uniqId, scrapedAt]
# Index: []
#
# [0 rows x 21 columns]

# %%
# duplicate remove 
data.drop_duplicates(inplace = True)

# %%
# using isnull()
data.isnull()
# Out:
#        url   name  contentType  description  contentRating  genre  poster  \
# 0    False  False        False        False          False  False   False
# 1    False  False        False        False          False  False   False
# 2    False  False        False        False          False  False   False
# 3    False  False        False        False          False  False   False
# 4    False  False        False        False          False  False   False
# ..     ...    ...          ...          ...            ...    ...     ...
# 143  False  False        False        False          False  False   False
# 144  False  False        False        False          False  False   False
# 145  False  False        False        False          False  False   False
# 146  False  False        False        False          False  False   False
# 147  False  False        False        False          False  False   False
#
#      formattedDuration  releasedDate  actors  ...  creator  audio  subtitle  \
# ...

# %%
# sum() - for count the null values
data.isnull().sum()
# Out:
# url                      0
# name                     0
# contentType              0
# description              0
# contentRating            0
# genre                    0
# poster                   0
# formattedDuration      105
# releasedDate             0
# actors                  16
# director                97
# creator                 74
# audio                  105
# subtitle               105
# availableForOffline      0
# numberOfSeasons         43
# seasonStartDate         43
# source                   0
# sourceLink               0
# uniqId                   0
# scrapedAt                0
# dtype: int64

# %%
# heatmap
import pandas as pd
data = pd.read_csv(r'C:\Users\vishal\Downloads\netflix_movies.csv')
import seaborn as sb
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#isin() and str.contains()
data[data['name'].isin(['Space Force'])]
# Out:
#                                         url         name contentType  \
# 143  https://www.netflix.com/title/81021929  Space Force    TVSeries
#
#                                            description contentRating  \
# 143  A four-star general begrudgingly teams up with...           16+
#
#            genre                                             poster  \
# 143  TV Comedies  https://occ-0-1492-1007.1.nflxso.net/dnm/api/v...
#
#     formattedDuration releasedDate  \
# 143               NaN    2020-5-29
#
#                                                 actors  ...  \
# 143  Steve Carell, John Malkovich, Ben Schwartz, Di...  ...
#
#                         creator audio subtitle    availableForOffline  \
# 143  Steve Carell, Greg Daniels   NaN      NaN  Available to download
#
#     numberOfSeasons  seasonStartDate   source           sourceLink  \
# 143             2.0        2020-5-29  Netflix  https://netflix.com
#
# ...

# %%
#dtypes
data.dtypes
# Out:
# url                     object
# name                    object
# contentType             object
# description             object
# contentRating           object
# genre                   object
# poster                  object
# formattedDuration       object
# releasedDate            object
# actors                  object
# director                object
# creator                 object
# audio                   object
# subtitle                object
# availableForOffline     object
# numberOfSeasons        float64
# seasonStartDate         object
# source                  object
# sourceLink              object
# uniqId                  object
# scrapedAt               object
# dtype: object

# %%
# to_datetime
data['Date_n'] = pd.to_datetime(data['releasedDate'])

# %%
data
# Out:
# url                            object
# name                           object
# contentType                    object
# description                    object
# contentRating                  object
# genre                          object
# poster                         object
# formattedDuration              object
# releasedDate                   object
# actors                         object
# director                       object
# creator                        object
# audio                          object
# subtitle                       object
# availableForOffline            object
# numberOfSeasons               float64
# seasonStartDate                object
# source                         object
# sourceLink                     object
# uniqId                         object
# scrapedAt                      object
# Date_n                 datetime64[ns]
# dtype: object

# %%
# dt.year.value_counts()
data['Date_n'].dt.year.value_counts()
# Out:
# 2021    46
# 2022    32
# 2019    22
# 2020    19
# 2018    14
# 2016     8
# 2017     6
# 2015     1
# Name: Date_n, dtype: int64

# %%
# bar graph
data['Date_n'].dt.year.value_counts().plot( kind='bar')
# Out:
# <Axes: >

# %%
#groupby
data.groupby('contentType').contentType.count()
# Out:
# contentType
# Movie        43
# TVSeries    105
# Name: contentType, dtype: int64

# %%
data['Date_n'] = pd.to_datetime(data['releasedDate'])

# %%
# create new column year
data['year'] = data['Date_n'].dt.year

# %%
data.head()
# Out:
#                                       url  \
# 0  https://www.netflix.com/title/80189221
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                name contentType  \
# 0                        The Haunting of Hill House    TVSeries
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          description contentRating  \
# 0  Flashing between past and present, a fractured...           18+
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %%
# Filter method
data [(data['contentType'] == 'TVSeries') & (data['year']==2020)]
# Out:
#                                         url                            name  \
# 2    https://www.netflix.com/title/80996601                   Love Is Blind
# 13   https://www.netflix.com/title/81037371                  Emily in Paris
# 38   https://www.netflix.com/title/80239866                 Sweet Magnolias
# 44   https://www.netflix.com/title/81011098                 Young Wallander
# 45   https://www.netflix.com/title/80232398                      Bridgerton
# 68   https://www.netflix.com/title/80200575             Alice in Borderland
# 78   https://www.netflix.com/title/80179190               Never Have I Ever
# 91   https://www.netflix.com/title/81009646  Jurassic World Camp Cretaceous
# 110  https://www.netflix.com/title/81039393                           Cheer
# 111  https://www.netflix.com/title/80234304              The Queen's Gambit
# 132  https://www.netflix.com/title/80241239                     Locke & Key
# ...

# %%
# filter genre
data[(data['genre']=='US Movies') & (data['contentType']=='Movie')] ['name']
# Out:
# 3                       I Care a Lot
# 4                 tick, tick...BOOM!
# 8                        Tall Girl 2
# 9             The Devil All The Time
# 14              The Power of the Dog
# 15           Texas Chainsaw Massacre
# 18         Forgive Us Our Trespasses
# 25     I'm Thinking of Ending Things
# 31                          The King
# 33           The Woman in the Window
# 35                           Passing
# 49                         Home Team
# 61      The Ballad of Buster Scruggs
# 63                        Red Notice
# 73                      The Irishman
# 94                 The Lost Daughter
# 104       The Trial of the Chicago 7
# 123               Always Be My Maybe
# 128                        The House
# 131                 The Unforgivable
# 134             Fistful of Vengeance
# 141                       The Guilty
# Name: name, dtype: object

# %%
data[data['actors'].str.contains('Andrew Garfield')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 data[data['actors'].str.contains('Andrew Garfield')]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
#create a data frame dropna()
new_data =data.dropna()
new_data.head()
# Out:
# Empty DataFrame
# Columns: [url, name, contentType, description, contentRating, genre, poster, formattedDuration, releasedDate, actors, director, creator, audio, subtitle, availableForOffline, numberOfSeasons, seasonStartDate, source, sourceLink, uniqId, scrapedAt, Date_n, year]
# Index: []
#
# [0 rows x 23 columns]

# %%
new_data[new_data['actors'].str.contains('Andrew Garfield')]
# Out:
# Empty DataFrame
# Columns: [url, name, contentType, description, contentRating, genre, poster, formattedDuration, releasedDate, actors, director, creator, audio, subtitle, availableForOffline, numberOfSeasons, seasonStartDate, source, sourceLink, uniqId, scrapedAt, Date_n, year]
# Index: []
#
# [0 rows x 23 columns]

# %%
'shape' use to record count
# Out:
#   Input In [24]
#     'shape' use to record count
#             ^
# SyntaxError: invalid syntax

# %%
# filtring by contentRating,year
data[(data['contentType']=='Movie') & (data['contentRating']=='18+')].shape
data[(data['contentType']=='Movie') & (data['contentRating']=='18+') & (data['year'] >2020) ]
# Out:
#                                         url                     name  \
# 3    https://www.netflix.com/title/81350429             I Care a Lot
# 15   https://www.netflix.com/title/81483977  Texas Chainsaw Massacre
# 22   https://www.netflix.com/title/81410539            The Privilege
# 27   https://www.netflix.com/title/81388078        Through My Window
# 33   https://www.netflix.com/title/81092222  The Woman in the Window
# 41   https://www.netflix.com/title/81158472                   Bigbug
# 87   https://www.netflix.com/title/81140667       Ali Wong: Don Wong
# 94   https://www.netflix.com/title/81478910        The Lost Daughter
# 103  https://www.netflix.com/title/81513706               Procession
# 107  https://www.netflix.com/title/81156325          The Hand of God
# 131  https://www.netflix.com/title/81028975         The Unforgivable
# 134  https://www.netflix.com/title/80240904     Fistful of Vengeance
# 135  https://www.netflix.com/title/81252357            Don't Look Up
#
# ...

# %%
# show the Duration in array format
data.formattedDuration.unique()
# Out:
# array([nan, '1h 59m', '1h 55m', '2h 9m', '1h 41m', '2h 18m', '2h 1m',
#        '2h 8m', '1h 23m', '14m', '2h 12m', '1h 47m', '2h 14m', '1h 53m',
#        '2h 20m', '1h 29m', '1h 39m', '1h 51m', '40m', '2h 13m', '32m',
#        '1h 57m', '22m', '3h 29m', '2h 19m', '1h 43m', '59m', '2h 2m',
#        '1h 54m', '38m', '1h 58m', '2h 10m', '1h 38m', '1h 42m', '1h 25m',
#        '1h 37m', '1h 36m', '1h 31m'], dtype=object)

# %%
#splt the Duration and create a new column
data[['min','unit']] = data['formattedDuration'].str.split(' ',expand=True)
data.head()

# %%
tv_series = data[data['contentType']=='TVSeries']
tv_series
# Out:
#                                         url  \
# 0    https://www.netflix.com/title/80189221
# 1    https://www.netflix.com/title/81031373
# 2    https://www.netflix.com/title/80996601
# 5    https://www.netflix.com/title/81083626
# 6    https://www.netflix.com/title/80180171
# ..                                      ...
# 142  https://www.netflix.com/title/80044950
# 143  https://www.netflix.com/title/81021929
# 144  https://www.netflix.com/title/81123055
# 145  https://www.netflix.com/title/81036622
# 147  https://www.netflix.com/title/81435684
#
#                                                  name contentType  \
# 0                          The Haunting of Hill House    TVSeries
# 1    Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                       Love Is Blind    TVSeries
# 5                                       Midnight Mass    TVSeries
# 6                                             Kingdom    TVSeries
# ...

# %%
#finding the count of genre of tv series
tv_series.genre.value_counts().head(1)
# Out:
# TV Mysteries    24
# Name: genre, dtype: int64
